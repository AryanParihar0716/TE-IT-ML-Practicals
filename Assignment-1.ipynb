# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('dataset_Facebook(2).csv',sep=';')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
df.isnull()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0               False  False     False       False         False      False
# 1               False  False     False       False         False      False
# 2               False  False     False       False         False      False
# 3               False  False     False       False         False      False
# 4               False  False     False       False         False      False
# ..                ...    ...       ...         ...           ...        ...
# 495             False  False     False       False         False      False
# 496             False  False     False       False         False      False
# 497             False  False     False       False         False      False
# 498             False  False     False       False         False      False
# 499             False  False     False       False         False      False
#
# ...

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df=df.fillna(0)

# %%
(df==0).sum()
# Out:
# Page total likes                                                         0
# Type                                                                     0
# Category                                                                 0
# Post Month                                                               0
# Post Weekday                                                             0
# Post Hour                                                                0
# Paid                                                                   361
# Lifetime Post Total Reach                                                0
# Lifetime Post Total Impressions                                          0
# Lifetime Engaged Users                                                   0
# Lifetime Post Consumers                                                  0
# Lifetime Post Consumptions                                               0
# ...

# %%
df.dtypes
# Out:
# Page total likes                                                         int64
# Type                                                                    object
# Category                                                                 int64
# Post Month                                                               int64
# Post Weekday                                                             int64
# Post Hour                                                                int64
# Paid                                                                   float64
# Lifetime Post Total Reach                                                int64
# Lifetime Post Total Impressions                                          int64
# Lifetime Engaged Users                                                   int64
# Lifetime Post Consumers                                                  int64
# Lifetime Post Consumptions                                               int64
# ...

# %%
#SubSet Creation

# %%
set1=df[['Type']]
set1
# Out:
#        Type
# 0     Photo
# 1    Status
# 2     Photo
# 3     Photo
# 4     Photo
# ..      ...
# 495   Photo
# 496   Photo
# 497   Photo
# 498   Photo
# 499   Photo
#
# [500 rows x 1 columns]

# %%
set2=df[['Paid']]
set2
# Out:
#      Paid
# 0     0.0
# 1     0.0
# 2     0.0
# 3     1.0
# 4     0.0
# ..    ...
# 495   0.0
# 496   0.0
# 497   0.0
# 498   0.0
# 499   0.0
#
# [500 rows x 1 columns]

# %%
set3=df[['like','share']]

# %%
set3
# Out:
#        like  share
# 0      79.0   17.0
# 1     130.0   29.0
# 2      66.0   14.0
# 3    1572.0  147.0
# 4     325.0   49.0
# ..      ...    ...
# 495    53.0   26.0
# 496    53.0   22.0
# 497    93.0   18.0
# 498    91.0   38.0
# 499    91.0   28.0
#
# [500 rows x 2 columns]

# %%
set4=df.loc[:,'Page total likes':'Lifetime Post Total Impressions']

# %%
set4
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
set5=df[(df['Lifetime Post Total Reach']>1000) & (df['Lifetime Post Total Impressions']>1000)]

# %%
set5
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
set6=df[(df['Type']=='Photo') & (df['Lifetime Post Total Impressions']>1000)]

# %%
set6
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
set7=df.loc[:,'Page total likes':'Lifetime Post Impressions by people who have liked your Page']

# %%
set7
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
small_set1=df.iloc[0:4,0:3]

# %%
small_set1
# Out:
#    Page total likes    Type  Category
# 0            139441   Photo         2
# 1            139441  Status         2
# 2            139441   Photo         3
# 3            139441   Photo         2

# %%
small_set2=df.iloc[0:6,0:3]

# %%
small_set2
# Out:
#    Page total likes    Type  Category
# 0            139441   Photo         2
# 1            139441  Status         2
# 2            139441   Photo         3
# 3            139441   Photo         2
# 4            139441   Photo         2
# 5            139441  Status         2

# %%
#Row Merge
row_m=pd.concat([small_set1,small_set2],ignore_index=True)

# %%
row_m
# Out:
#    Page total likes    Type  Category
# 0            139441   Photo         2
# 1            139441  Status         2
# 2            139441   Photo         3
# 3            139441   Photo         2
# 4            139441   Photo         2
# 5            139441  Status         2
# 6            139441   Photo         3
# 7            139441   Photo         2
# 8            139441   Photo         2
# 9            139441  Status         2

# %%
small_set3=df.iloc[0:4,0:3]

# %%
small_set4=df.iloc[0:2,1:3]

# %%
#Column Merge
col_m=pd.concat([small_set3, small_set4], join="inner",ignore_index=True)

# %%
col_m
# Out:
#      Type  Category
# 0   Photo         2
# 1  Status         2
# 2   Photo         3
# 3   Photo         2
# 4   Photo         2
# 5  Status         2

# %%
#Transpose
transposed_set=small_set1.transpose()

# %%
transposed_set
# Out:
#                        0       1       2       3
# Page total likes  139441  139441  139441  139441
# Type               Photo  Status   Photo   Photo
# Category               2       2       3       2

# %%
#Reshape Of Data

# %%
table=pd.pivot_table(set6,values=["Page total likes","Category"],index=["Type","Paid"],aggfunc={"Page total likes":"mean","Category":"mean"})

# %%
table
# Out:
#             Category  Page total likes
# Type  Paid
# Photo 0.0   1.927632     122564.187500
#       1.0   1.915966     122351.159664
